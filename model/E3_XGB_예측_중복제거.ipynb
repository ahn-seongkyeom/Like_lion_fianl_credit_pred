# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, accuracy_score
import xgboost as xgb

# %%
test_df = pd.read_csv('merge/result/E2_XGb_예측.csv')
sample = pd.read_csv('merge/result/sample_submission.csv')

test_df
# Out:
#                 ID Predicted_Segment
# 0       TEST_00000                 E
# 1       TEST_00001                 E
# 2       TEST_00002                 D
# 3       TEST_00003                 E
# 4       TEST_00004                 E
# ...            ...               ...
# 599995  TEST_99995                 E
# 599996  TEST_99996                 E
# 599997  TEST_99997                 E
# 599998  TEST_99998                 C
# 599999  TEST_99999                 E
#
# [600000 rows x 2 columns]

# %%
# 중복 ID 제거 (가장 첫 번째 등장한 row만 남김)
test_unique = test_df.drop_duplicates(subset='ID', keep='first').copy()

# 결과 확인 (선택)
print("중복 제거 전:", len(test_df))
print("중복 제거 후:", len(test_unique))
# Out:
# 중복 제거 전: 600000
# 중복 제거 후: 100000

# %%
test_unique['Predicted_Segment'].value_counts()
# Out:
# Predicted_Segment
# E    83725
# D    12377
# C     3747
# A       87
# B       64
# Name: count, dtype: int64

# %%
test_unique.to_csv('merge/result/E3_XGB_예측_중복제거.csv', index=False, encoding='utf-8-sig')
