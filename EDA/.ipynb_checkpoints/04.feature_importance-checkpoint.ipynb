# %%
import lightgbm as lgb
import pandas as pd
import pickle

# %%
# 파일 경로
file_path = 'C:/final_prj/open/LGBM_model.pkl'  # 또는 'data.pickle'

# 피클 파일 열기
with open(file_path, 'rb') as f:
    data = pickle.load(f)
# Out:
# C:\Users\a2068\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.1 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# 학습 예시
model = lgb.LGBMClassifier()
model.fit(X_train, y_train)

# Feature importance 추출
importance = model.feature_importances_
feature_names = X_train.columns

# DataFrame으로 정리
importance_df = pd.DataFrame({
    'feature': feature_names,
    'importance': importance
}).sort_values(by='importance', ascending=False)

print(importance_df)
