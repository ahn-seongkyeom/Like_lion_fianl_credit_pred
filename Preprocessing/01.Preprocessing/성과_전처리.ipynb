# %%
import pandas as pd
import os
from glob import glob
import numpy as np
from pandas.api.types import CategoricalDtype

# %%
ex1 = pd.read_parquet('train/8.성과정보/2018_성과정보_전체.parquet')

# %%
member_df = pd.read_parquet('train/1.회원정보/2018_회원정보_전체.parquet')
member_seg = member_df[['ID', 'Segment']].drop_duplicates(subset='ID')
ex1 = ex1.merge(member_seg, on='ID', how='left')

# %%
all_cols = ex1.columns.tolist()
print("전체 컬럼 이름:")
print(all_cols)
str_cols = ex1.select_dtypes(include=['object']).columns.tolist()
print("\n문자형 컬럼 이름:")
print(str_cols)
num_cols = ex1.select_dtypes(include=[np.number]).columns.tolist()
print("\n숫자형 컬럼 이름:")
print(num_cols)
# Out:
# 전체 컬럼 이름:
# ['기준년월', 'ID', '증감율_이용건수_신용_전월', '증감율_이용건수_신판_전월', '증감율_이용건수_일시불_전월', '증감율_이용건수_할부_전월', '증감율_이용건수_CA_전월', '증감율_이용건수_체크_전월', '증감율_이용건수_카드론_전월', '증감율_이용금액_신용_전월', '증감율_이용금액_신판_전월', '증감율_이용금액_일시불_전월', '증감율_이용금액_할부_전월', '증감율_이용금액_CA_전월', '증감율_이용금액_체크_전월', '증감율_이용금액_카드론_전월', '증감율_이용건수_신용_분기', '증감율_이용건수_신판_분기', '증감율_이용건수_일시불_분기', '증감율_이용건수_할부_분기', '증감율_이용건수_CA_분기', '증감율_이용건수_체크_분기', '증감율_이용건수_카드론_분기', '증감율_이용금액_신용_분기', '증감율_이용금액_신판_분기', '증감율_이용금액_일시불_분기', '증감율_이용금액_할부_분기', '증감율_이용금액_CA_분기', '증감율_이용금액_체크_분기', '증감율_이용금액_카드론_분기', '잔액_신판평균한도소진율_r6m', '잔액_신판최대한도소진율_r6m', '잔액_신판평균한도소진율_r3m', '잔액_신판최대한도소진율_r3m', '잔액_신판ca평균한도소진율_r6m', '잔액_신판ca최대한도소진율_r6m', '잔액_신판ca평균한도소진율_r3m', '잔액_신판ca최대한도소진율_r3m', '변동률_일시불평잔', '변동률_RV일시불평잔', '변동률_할부평잔', '변동률_CA평잔', '변동률_RVCA평잔', '변동률_카드론평잔', '변동률_잔액_B1M', '변동률_잔액_일시불_B1M', '변동률_잔액_CA_B1M', '혜택수혜율_R3M', '혜택수혜율_B0M', 'Segment']
#
# 문자형 컬럼 이름:
# ['ID', 'Segment']
#
# 숫자형 컬럼 이름:
# ['기준년월', '증감율_이용건수_신용_전월', '증감율_이용건수_신판_전월', '증감율_이용건수_일시불_전월', '증감율_이용건수_할부_전월', '증감율_이용건수_CA_전월', '증감율_이용건수_체크_전월', '증감율_이용건수_카드론_전월', '증감율_이용금액_신용_전월', '증감율_이용금액_신판_전월', '증감율_이용금액_일시불_전월', '증감율_이용금액_할부_전월', '증감율_이용금액_CA_전월', '증감율_이용금액_체크_전월', '증감율_이용금액_카드론_전월', '증감율_이용건수_신용_분기', '증감율_이용건수_신판_분기', '증감율_이용건수_일시불_분기', '증감율_이용건수_할부_분기', '증감율_이용건수_CA_분기', '증감율_이용건수_체크_분기', '증감율_이용건수_카드론_분기', '증감율_이용금액_신용_분기', '증감율_이용금액_신판_분기', '증감율_이용금액_일시불_분기', '증감율_이용금액_할부_분기', '증감율_이용금액_CA_분기', '증감율_이용금액_체크_분기', '증감율_이용금액_카드론_분기', '잔액_신판평균한도소진율_r6m', '잔액_신판최대한도소진율_r6m', '잔액_신판평균한도소진율_r3m', '잔액_신판최대한도소진율_r3m', '잔액_신판ca평균한도소진율_r6m', '잔액_신판ca최대한도소진율_r6m', '잔액_신판ca평균한도소진율_r3m', '잔액_신판ca최대한도소진율_r3m', '변동률_일시불평잔', '변동률_RV일시불평잔', '변동률_할부평잔', '변동률_CA평잔', '변동률_RVCA평잔', '변동률_카드론평잔', '변동률_잔액_B1M', '변동률_잔액_일시불_B1M', '변동률_잔액_CA_B1M', '혜택수혜율_R3M', '혜택수혜율_B0M']

# %%
ex1 = ex1.fillna(-1)

# %%
num_df = ex1.select_dtypes(include=[np.number]).dropna()
low_var = num_df.var()[ num_df.var() < 0.01 ].index.tolist()
low_var
# Out:
# ['증감율_이용건수_체크_전월', '증감율_이용건수_카드론_전월', '증감율_이용금액_카드론_전월', '변동률_잔액_CA_B1M']

# %%
cols_to_drop = ['증감율_이용건수_체크_전월', '증감율_이용건수_카드론_전월', '증감율_이용금액_카드론_전월', '변동률_잔액_CA_B1M']

ex1.drop(columns=cols_to_drop, inplace=True)

# %%
missing_mask = ex1.isna() | (ex1 == -1)
missing_ratio = missing_mask.mean()

high_na = missing_ratio[missing_ratio > 0.2].index.tolist()

high_const_cols = []
threshold_const = 0.8

for col in ex1.columns:
    top_ratio = ex1[col].value_counts(normalize=True, dropna=False).values[0]
    if top_ratio > threshold_const:
        high_const_cols.append(col)

to_drop = list(set(high_na + high_const_cols))

if 'Segment' in to_drop:
    to_drop.remove('Segment')

print("삭제 대상 컬럼 (결측>20% 또는 동일값>80%):", to_drop)

ex1.drop(columns=to_drop, inplace=True)
# Out:
# 삭제 대상 컬럼 (결측>20% 또는 동일값>80%): ['증감율_이용건수_카드론_분기', '증감율_이용금액_카드론_분기', '증감율_이용건수_할부_전월', '증감율_이용금액_CA_전월', '변동률_카드론평잔', '증감율_이용건수_CA_분기', '증감율_이용금액_체크_분기', '변동률_CA평잔', '증감율_이용금액_할부_전월', '혜택수혜율_B0M', '증감율_이용금액_CA_분기', '증감율_이용금액_체크_전월', '변동률_RVCA평잔', '혜택수혜율_R3M', '증감율_이용건수_체크_분기', '증감율_이용건수_CA_전월']

# %%
num_df = ex1.select_dtypes(include=[np.number]).dropna()

corr = num_df.corr().abs()

high_corr_pairs = (
    corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
        .stack()
        .reset_index()
)
high_corr_pairs.columns = ['Feature_1', 'Feature_2', 'Correlation']
high_corr_pairs = high_corr_pairs[high_corr_pairs['Correlation'] > 0.8]

if not np.issubdtype(ex1['Segment'].dtype, np.number):
    segment_map = {label: idx for idx, label in enumerate(sorted(ex1['Segment'].unique()))}
    ex1['Segment_encoded'] = ex1['Segment'].map(segment_map)
else:
    ex1['Segment_encoded'] = ex1['Segment']

segment_corr = ex1[num_df.columns].corrwith(ex1['Segment_encoded']).abs()

high_corr_pairs['Corr_with_Segment_1'] = high_corr_pairs['Feature_1'].map(segment_corr)
high_corr_pairs['Corr_with_Segment_2'] = high_corr_pairs['Feature_2'].map(segment_corr)

high_corr_pairs = high_corr_pairs.sort_values(by='Correlation', ascending=False).reset_index(drop=True)

print(f"▶ 상관계수 초과 변수쌍 수: {len(high_corr_pairs)}")
display(high_corr_pairs)
# Out:
# ▶ 상관계수 초과 변수쌍 수: 50
#              Feature_1           Feature_2  Correlation  Corr_with_Segment_1  \
# 0     잔액_신판평균한도소진율_r3m    잔액_신판최대한도소진율_r3m     0.994910             0.189758
# 1   잔액_신판ca평균한도소진율_r3m  잔액_신판ca최대한도소진율_r3m     0.994069             0.258636
# 2       증감율_이용건수_신용_전월      증감율_이용건수_신판_전월     0.988043             0.004801
# 3       증감율_이용건수_신용_분기      증감율_이용건수_신판_분기     0.986543             0.000929
# 4   잔액_신판ca평균한도소진율_r6m  잔액_신판ca최대한도소진율_r6m     0.986143             0.252525
# 5     잔액_신판평균한도소진율_r6m    잔액_신판최대한도소진율_r6m     0.985459             0.181995
# 6       증감율_이용금액_신용_분기      증감율_이용금액_신판_분기     0.983909             0.014716
# 7     잔액_신판평균한도소진율_r6m    잔액_신판평균한도소진율_r3m     0.983587             0.181995
# 8     잔액_신판최대한도소진율_r6m    잔액_신판최대한도소진율_r3m     0.981763             0.200087
# 9   잔액_신판ca최대한도소진율_r6m  잔액_신판ca최대한도소진율_r3m     0.979922             0.268486
# 10  잔액_신판ca평균한도소진율_r6m  잔액_신판ca평균한도소진율_r3m     0.979714             0.252525
# 11    잔액_신판평균한도소진율_r6m    잔액_신판최대한도소진율_r3m     0.978865             0.181995
# 12      증감율_이용금액_신용_전월      증감율_이용금액_신판_전월     0.977513             0.046525
# 13  잔액_신판ca평균한도소진율_r6m  잔액_신판ca최대한도소진율_r3m     0.976896             0.252525
# 14    잔액_신판최대한도소진율_r6m    잔액_신판평균한도소진율_r3m     0.974964             0.200087
# 15  잔액_신판ca최대한도소진율_r6m  잔액_신판ca평균한도소진율_r3m     0.973151             0.268486
# 16      증감율_이용건수_신판_분기     증감율_이용건수_일시불_분기     0.969789             0.000335
# 17      증감율_이용건수_신용_분기     증감율_이용건수_일시불_분기     0.959067             0.000929
# 18      증감율_이용금액_신판_분기     증감율_이용금액_일시불_분기     0.957265             0.013519
# 19      증감율_이용건수_신판_전월     증감율_이용건수_일시불_전월     0.955770             0.005583
# 20     증감율_이용건수_일시불_분기     증감율_이용금액_일시불_분기     0.953712             0.001071
# 21      증감율_이용금액_신판_전월     증감율_이용금액_일시불_전월     0.953500             0.073436
# 22      증감율_이용건수_신용_전월     증감율_이용건수_일시불_전월     0.946005             0.004801
# 23      증감율_이용금액_신용_분기     증감율_이용금액_일시불_분기     0.944427             0.014716
# 24      증감율_이용건수_신판_분기      증감율_이용금액_신판_분기     0.936049             0.000335
# 25      증감율_이용금액_신용_전월     증감율_이용금액_일시불_전월     0.934742             0.046525
# 26    잔액_신판최대한도소진율_r6m  잔액_신판ca최대한도소진율_r6m     0.933876             0.200087
# 27      증감율_이용건수_신판_분기     증감율_이용금액_일시불_분기     0.930512             0.000335
# 28      증감율_이용건수_신용_분기      증감율_이용금액_신용_분기     0.927914             0.000929
# 29    잔액_신판최대한도소진율_r3m  잔액_신판ca최대한도소진율_r3m     0.925586             0.194820
# 30      증감율_이용건수_신용_분기      증감율_이용금액_신판_분기     0.925382             0.000929
# 31    잔액_신판평균한도소진율_r6m  잔액_신판ca평균한도소진율_r6m     0.924493             0.181995
# 32    잔액_신판평균한도소진율_r6m  잔액_신판ca최대한도소진율_r6m     0.924144             0.181995
# 33    잔액_신판평균한도소진율_r3m  잔액_신판ca최대한도소진율_r3m     0.923374             0.189758
# 34      증감율_이용건수_신판_분기      증감율_이용금액_신용_분기     0.920839             0.000335
# 35      증감율_이용건수_신용_분기     증감율_이용금액_일시불_분기     0.920813             0.000929
# 36    잔액_신판평균한도소진율_r3m  잔액_신판ca평균한도소진율_r3m     0.918874             0.189758
# 37    잔액_신판최대한도소진율_r3m  잔액_신판ca최대한도소진율_r6m     0.918075             0.194820
# 38    잔액_신판최대한도소진율_r3m  잔액_신판ca평균한도소진율_r3m     0.915553             0.194820
# 39     증감율_이용건수_일시불_분기      증감율_이용금액_신판_분기     0.914311             0.001071
# 40    잔액_신판평균한도소진율_r3m  잔액_신판ca최대한도소진율_r6m     0.914301             0.189758
# 41    잔액_신판평균한도소진율_r3m  잔액_신판ca평균한도소진율_r6m     0.910656             0.189758
# 42    잔액_신판최대한도소진율_r6m  잔액_신판ca평균한도소진율_r6m     0.910243             0.200087
# 43    잔액_신판최대한도소진율_r6m  잔액_신판ca최대한도소진율_r3m     0.908427             0.200087
# 44    잔액_신판평균한도소진율_r6m  잔액_신판ca최대한도소진율_r3m     0.905998             0.181995
# 45    잔액_신판최대한도소진율_r3m  잔액_신판ca평균한도소진율_r6m     0.904410             0.194820
# 46    잔액_신판평균한도소진율_r6m  잔액_신판ca평균한도소진율_r3m     0.903186             0.181995
# 47     증감율_이용건수_일시불_분기      증감율_이용금액_신용_분기     0.901846             0.001071
# 48    잔액_신판최대한도소진율_r6m  잔액_신판ca평균한도소진율_r3m     0.896515             0.200087
# 49      증감율_이용건수_할부_분기      증감율_이용금액_할부_분기     0.864796             0.036098
#
#     Corr_with_Segment_2
# 0              0.194820
# 1              0.263688
# 2              0.005583
# 3              0.000335
# 4              0.268486
# 5              0.200087
# 6              0.013519
# 7              0.189758
# 8              0.194820
# 9              0.263688
# 10             0.258636
# 11             0.194820
# 12             0.073436
# 13             0.263688
# 14             0.189758
# 15             0.258636
# 16             0.001071
# 17             0.001071
# 18             0.006105
# 19             0.008263
# 20             0.006105
# 21             0.073526
# 22             0.008263
# 23             0.006105
# 24             0.013519
# 25             0.073526
# 26             0.268486
# 27             0.006105
# 28             0.014716
# 29             0.263688
# 30             0.013519
# 31             0.252525
# 32             0.268486
# 33             0.263688
# 34             0.014716
# 35             0.006105
# 36             0.258636
# 37             0.268486
# 38             0.258636
# 39             0.013519
# 40             0.268486
# 41             0.252525
# 42             0.252525
# 43             0.263688
# 44             0.263688
# 45             0.252525
# 46             0.258636
# 47             0.014716
# 48             0.258636
# 49             0.028412

# %%
to_drop = []

for _, row in high_corr_pairs.iterrows():
    f1, f2 = row['Feature_1'], row['Feature_2']
    c1, c2 = row['Corr_with_Segment_1'], row['Corr_with_Segment_2']
    
    if pd.isna(c1) or pd.isna(c2):
        continue
    
    if c1 < c2:
        to_drop.append(f1)
    else:
        to_drop.append(f2)

to_drop = list(set(to_drop))

print(f"▶ 제거 대상 피처 수: {len(to_drop)}")
print("제거할 피처 목록:")
print(to_drop)
# Out:
# ▶ 제거 대상 피처 수: 17
# 제거할 피처 목록:
# ['잔액_신판평균한도소진율_r6m', '증감율_이용금액_일시불_분기', '잔액_신판최대한도소진율_r3m', '잔액_신판평균한도소진율_r3m', '잔액_신판ca평균한도소진율_r6m', '증감율_이용건수_신판_전월', '증감율_이용건수_일시불_분기', '잔액_신판ca평균한도소진율_r3m', '증감율_이용금액_신판_전월', '증감율_이용금액_할부_분기', '증감율_이용금액_신용_전월', '증감율_이용건수_신용_분기', '잔액_신판ca최대한도소진율_r3m', '증감율_이용건수_신용_전월', '증감율_이용건수_신판_분기', '잔액_신판최대한도소진율_r6m', '증감율_이용금액_신판_분기']

# %%
cols_to_drop = ['잔액_신판평균한도소진율_r6m', '증감율_이용금액_일시불_분기', '잔액_신판최대한도소진율_r3m', '잔액_신판평균한도소진율_r3m', '잔액_신판ca평균한도소진율_r6m', '증감율_이용건수_신판_전월', '증감율_이용건수_일시불_분기', '잔액_신판ca평균한도소진율_r3m', '증감율_이용금액_신판_전월', '증감율_이용금액_할부_분기', '증감율_이용금액_신용_전월', '증감율_이용건수_신용_분기', '잔액_신판ca최대한도소진율_r3m', '증감율_이용건수_신용_전월', '증감율_이용건수_신판_분기', '잔액_신판최대한도소진율_r6m', '증감율_이용금액_신판_분기']
ex1.drop(columns=cols_to_drop, inplace=True)

# %%
from statsmodels.tools.tools import add_constant
from statsmodels.stats.outliers_influence import variance_inflation_factor

num_df = (
    ex1
    .select_dtypes(include=[np.number])
    .drop(columns=['기준년월'], errors='ignore')
    .dropna()
)


X = add_constant(num_df)

vif_df = pd.DataFrame({
    'feature': X.columns,
    'VIF': [variance_inflation_factor(X.values, i)
            for i in range(X.shape[1])]
})

vif_df = vif_df[vif_df['feature'] != 'const'].reset_index(drop=True)

high_vif = vif_df[vif_df['VIF'] > 10]

print("VIF > 10인 컬럼들:", high_vif['feature'].tolist())
print(high_vif)
# Out:
# VIF > 10인 컬럼들: []
# Empty DataFrame
# Columns: [feature, VIF]
# Index: []

# %%
ex1
# Out:
#            기준년월            ID  증감율_이용건수_일시불_전월  증감율_이용금액_일시불_전월  \
# 0        201807  TRAIN_000000         0.364727         0.313300
# 1        201807  TRAIN_000001        -0.511808        -1.010817
# 2        201807  TRAIN_000002         0.067843         0.289565
# 3        201807  TRAIN_000003         0.153975         0.276947
# 4        201807  TRAIN_000004         0.000000         0.000028
# ...         ...           ...              ...              ...
# 2399995  201812  TRAIN_399995         0.000000         0.000027
# 2399996  201812  TRAIN_399996         0.073804         0.207099
# 2399997  201812  TRAIN_399997        -0.040432         0.229573
# 2399998  201812  TRAIN_399998         0.000000         0.000034
# 2399999  201812  TRAIN_399999         0.187598         0.284271
#
#          증감율_이용건수_할부_분기  증감율_이용금액_신용_분기  잔액_신판ca최대한도소진율_r6m  변동률_일시불평잔  \
# 0              0.000000       -0.411320            0.849842   0.951930
# 1              0.000000        0.552668            0.851009   1.290439
# 2              1.999996        0.139121            0.938161   0.929196
# 3              0.000000        0.103217            1.135424   1.020964
# 4              0.000000       -1.999996            0.000000   0.000000
# ...                 ...             ...                 ...        ...
# 2399995        0.000000        0.000000            0.032439   0.999998
# 2399996        0.000000       -0.792478            0.168081   0.615087
# 2399997        1.999996        0.042752            0.190393   1.036370
# 2399998        0.000000        0.000000            0.012677   0.999998
# 2399999        0.000000        0.287903            0.053036   1.080614
#
#          변동률_RV일시불평잔  변동률_할부평잔  변동률_잔액_B1M  변동률_잔액_일시불_B1M Segment  \
# 0           0.999998  1.042805    0.261886        0.270752       D
# 1           1.092698  0.905663   -0.563388       -0.670348       E
# 2           1.006124  1.993590   -0.046516        0.058114       C
# 3           0.999998  1.050646    0.023821        0.258943       D
# 4           0.999998  0.999998    0.000000        0.000000       E
# ...              ...       ...         ...             ...     ...
# 2399995     0.999998  0.999998    0.000000        0.000000       E
# 2399996     0.999998  0.999998   -0.203251       -0.159143       D
# 2399997     0.999998  0.345027    0.027319        0.126581       C
# 2399998     0.999998  0.999998    0.000000        0.000000       E
# 2399999     0.999998  0.593160   -0.039845       -0.002659       E
#
#          Segment_encoded
# 0                      3
# 1                      4
# 2                      2
# 3                      3
# 4                      4
# ...                  ...
# 2399995                4
# 2399996                3
# 2399997                2
# 2399998                4
# 2399999                4
#
# [2400000 rows x 14 columns]

# %%
from sklearn.preprocessing import LabelEncoder

df_corr = ex1.drop(columns=['기준년월', 'ID']).copy()

le = LabelEncoder()
df_corr['Segment_encoded'] = le.fit_transform(df_corr['Segment'])

correlations = df_corr.corr(numeric_only=True)['Segment_encoded'].drop('Segment_encoded')

selected_cols = correlations[correlations.abs() > 0.1].index.tolist()

final_cols = ['기준년월', 'ID','Segment'] + selected_cols

ex1_filtered = ex1[final_cols]

# %%
cols = ex1_filtered.columns.tolist()
cols
# Out:
# ['기준년월', 'ID', 'Segment', '잔액_신판ca최대한도소진율_r6m', '변동률_RV일시불평잔']

# %%
ex1_filtered.to_parquet('성과_전처리_Segment.parquet', index=False)
